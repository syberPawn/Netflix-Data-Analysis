# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('netflix_titles.csv')

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
df['year_added'] = df['date_added'].dt.year

# %%
plt.figure(figsize=(12, 8))

# Subplot 1: Type count
plt.subplot(2, 2, 1)
sns.countplot(data=df, x='type')
plt.title("Movies vs TV Shows")

# Subplot 2: Year added
plt.subplot(2, 2, 2)
df['year_added'].value_counts().sort_index().plot(kind='bar')
plt.title("Titles Added Over Years")

# Subplot 3: Top genres
plt.subplot(2, 2, 3)
top_genres.plot(kind='barh')
plt.title("Top Genres")

# Subplot 4: Movie durations
plt.subplot(2, 2, 4)
movie_data = df[df['type'] == 'Movie']
sns.boxplot(data=movie_data, y='duration_int')
plt.title("Movie Duration (minutes)")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 15
#      13 # Subplot 3: Top genres
#      14 plt.subplot(2, 2, 3)
# ---> 15 top_genres.plot(kind='barh')
#      16 plt.title("Top Genres")
#      18 # Subplot 4: Movie durations
#
# NameError: name 'top_genres' is not defined
